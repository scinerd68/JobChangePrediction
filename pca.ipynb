# %%
import numpy as np

# %%
X_train = np.genfromtxt("Data/X_train.csv", delimiter=',')
y_train = np.genfromtxt("Data/y_train.csv", delimiter=',')

# %%
X_cv = np.genfromtxt("Data/X_cv.csv", delimiter=',')
y_cv = np.genfromtxt("Data/y_cv.csv", delimiter=',')

# %%
X_test = np.genfromtxt("Data/X_test.csv", delimiter=',')
y_test = np.genfromtxt("Data/y_test.csv", delimiter=',')

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2, random_state=42)

# %%
X_train = pca.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.30944983,  2.11164358],
#        [-1.87784622, -2.28362525],
#        [-1.07528848, -0.39028297],
#        ...,
#        [ 2.78069046,  2.20559528],
#        [-0.04924316, -1.56061481],
#        [-2.33607344,  0.01375737]])

# %%
X_train.shape
# Out:
# (11494, 2)

# %%
y_train.shape
# Out:
# (11494,)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, precision_score, recall_score

# %%
svm_clf = SVC(random_state=42, class_weight='balanced')

# %%
X_train.shape
# Out:
# (11494, 2)

# %%
svm_clf.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced', random_state=42)

# %%
y_train_pred = svm_clf.predict(X_train)

# %%
f1_score(y_train, y_train_pred)
# Out:
# 0.5351259689922481
